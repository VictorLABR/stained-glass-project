# %% [markdown]
# Briefing:
#
# •	Encontrar uma problemática da vida real que possa ser solucionada através de análise de dados e machine learning.
#
# De acordo com meu Projeto 1 sobre Análise de Crédito Bancário, pensei em estender para o tema “Detecção de fraudes financeiras”.
#
# •	A ideia do projeto é explanar e justificar a relevância do uso de dados para encontrar a solução.
#
# O setor financeiro é particularmente suscetível a fraudes, e as empresas precisam tomar medidas proativas para detectar e prevenir atividades fraudulentas. A análise de dados e machine learning pode ajudar a identificar padrões suspeitos nas transações financeiras e alertar as equipes de segurança em tempo real.
#
# As fraudes podem ocorrer em várias formas (roubo de identidade, cartões de crédito clonados, transações fraudulentas, lavagem de dinheiro, etc...). É essencial para as empresas financeiras detectar e prevenir essas atividades fraudulentas em tempo real para minimizar perdas financeiras e proteger a reputação da empresa.
#
# A análise de dados e machine learning podem ser usadas para detectar anomalias ou padrões suspeitos nas transações financeiras que podem indicar atividades fraudulentas. Esses padrões podem ser identificados usando modelos estatísticos e algoritmos de aprendizado de máquina treinados em grandes conjuntos de dados históricos.
#
# As redes neurais, por exemplo, podem ser treinadas em uma grande quantidade de dados históricos de transações financeiras rotuladas como: fraudulentas ou não fraudulentas. Esses modelos podem detectar padrões suspeitos em novas transações e gerar alertas em tempo real. Além disso, a análise de dados pode ser usada para identificar perfis de usuários suspeitos ou transações incomuns que possam estar relacionados à atividade fraudulenta. Isso pode incluir a análise de informações de geolocalização, histórico de transações, perfil do usuário, entre outros. A análise desses dados pode ser usada para desenvolver modelos preditivos que possam detectar transações fraudulentas antes que elas ocorram.
#
# •	Levante as fontes de dados públicas e não confidenciais para a coleta de informações.
# 1.	https://www.kaggle.com/datasets/paulosabinoreis/synthetic-financial-dataset-for-fraud-detection # análise inicial
# 2.	https://archive.ics.uci.edu/ml/index.php
# 3.	https://data.gov/
# 4.	https://fred.stlouisfed.org/

# %%
import pandas as pd
import numpy as np
import requests

Base_Dados = pd.read_csv("Base.csv")

Base_Dados.shape
# Out:
# (5090096, 11)

# %%
Base_Dados.sample(frac=0.1)
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 4345095   373   PAYMENT   14384.45   C742196299         336.00
# 4909622   396  CASH_OUT  413554.17  C1264585089       60949.00
# 4976765   204  CASH_OUT  251290.29   C824715704           0.00
# 1311514   187   CASH_IN    6129.11  C1691522681       51807.00
# 4732058   251  CASH_OUT  459779.53  C1054919471      334564.97
# ...       ...       ...        ...          ...            ...
# 634757    257  TRANSFER  403490.83   C384534399           0.00
# 1277552   188  TRANSFER   89129.65  C1924686464      327462.54
# 4736290   403   CASH_IN   55185.64   C706404326       38604.00
# 2000951   204   CASH_IN   39158.35  C1465485885    17663437.99
# 4758609    43   PAYMENT   12318.82  C1245691100           0.00
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  \
# 4345095            0.00   M292961519            0.00            0.00
# ...

# %%
Base_Dados.columns = ["Horas",
                     "Tipo",
                     "Quantia",
                     "ID",
                     "Antes_transacao",
                     "Depois_transacao",
                     ""]
